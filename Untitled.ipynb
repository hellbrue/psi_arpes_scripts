# %%
from scipy import signal
import math
import matplotlib.pyplot as plt
fig = plt.figure(frameon=False)
t = np.linspace(-0.04, 0.04, 2 * 10000, endpoint=False)
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
ax.set_axis_off()
fig.add_axes(ax)
q = signal.gausspulse(t, fc=250,bw=0.15,bwr=-7,tpr=-10)
#plt.arrow(0.95,0,0.1,0, head_width=0.06, overhang=.5, fill=False, edgecolor=None, capstyle='butt')
plt.plot(t, q, '-', color='lime', linewidth=6)

plt.savefig("green_pulse.svg", bbox_inches="tight", pad_inches=0, format='svg')
